# %% [markdown]
# # Delve Playground
#
# This notebook is **only for experimentation** — testing API calls, poking at responses, prototyping new tools before they get written into `src/`.
#
# The real product is `main.py` / `src/cli.py`. Nothing here needs to stay working long-term.

# %%
import sys

sys.path.append('.')  # so we can import config and src.* from project root

import config
from src.agent import Agent

config.validate_config()
print('Config OK, API key loaded.')
# Out:
# Config OK, API key loaded.

# %%
# Quick test of the brick-3 Agent, including multi-turn memory
agent = Agent()
print(agent.ask("What is 2 + 2?"))
print(agent.ask("What about 10 times that?"))  # should understand "that" refers to 4
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Quick test of the brick-3 Agent, including multi-turn memory
#       2 agent = Agent()
# ----> 3 print(agent.ask("What is 2 + 2?"))
#       4 print(agent.ask("What about 10 times that?"))  # should understand "that" refers to 4
#
# File c:\Users\hp\OneDrive\Desktop\delve\src\agent.py:33, in Agent.ask(self, user_message, max_retries)
#      31 for attempt in range(max_retries):
#      32     try:
# ---> 33         return self._conversation.send(user_message)
#      34     except errors.ServerError:
#      35         if attempt == max_retries - 1:
#
# File c:\Users\hp\OneDrive\Desktop\delve\src\memory\conversation.py:48, in Conversation.send(self, message)
#      46 def send(self, message: str) -> str:
#      47     """Send a message within this conversation and return the reply."""
# ---> 48     response = self._chat.send_message(message)
#      49     return response.text
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\google\genai\chats.py:258, in Chat.send_message(self, message, config)
#     254 method_config = config if config else self._config
#     255 method_config = _extra_utils.get_usage_header(
#     256     method_config, usage="chat"
#     257 )
# --> 258 response = self._modules.generate_content(
#     259     model=self._model,
#     260     contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#     261     config=method_config,
#     262 )
#     263 model_output = (
#     264     [response.candidates[0].content]
#     265     if response.candidates and response.candidates[0].content
#     266     else []
#     267 )
#     268 automatic_function_calling_history = (
#     269     response.automatic_function_calling_history
#     270     if response.automatic_function_calling_history
#     271     else []
#     272 )
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\google\genai\models.py:6596, in Models.generate_content(self, model, contents, config)
#    6592   parsed_config_to_call = _extra_utils.get_usage_header(
#    6593       parsed_config_to_call
#    6594   )
#    6595 i += 1
# -> 6596 response = self._generate_content(
#    6597     model=model, contents=contents, config=parsed_config_to_call
#    6598 )
#    6600 if not function_map:
#    6601   break
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\google\genai\models.py:5022, in Models._generate_content(self, model, contents, config)
#    5019 request_dict = _common.convert_to_dict(request_dict)
#    5020 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5022 response = self._api_client.request(
#    5023     'post', path, request_dict, http_options
#    5024 )
#    5026 if config is not None and getattr(
#    5027     config, 'should_return_http_response', None
#    5028 ):
#    5029   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\google\genai\_api_client.py:1708, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1698 def request(
#    1699     self,
#    1700     http_method: str,
#    (...)   1703     http_options: Optional[HttpOptionsOrDict] = None,
#    1704 ) -> SdkHttpResponse:
#    1705   http_request = self._build_request(
#    1706       http_method, path, request_dict, http_options
#    1707   )
# -> 1708   response = self._request(http_request, http_options, stream=False)
#    1709   response_body = (
#    1710       response.response_stream[0] if response.response_stream else ''
#    1711   )
#    1712   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\google\genai\_api_client.py:1495, in BaseApiClient._request(self, http_request, http_options, stream)
#    1492     retry = tenacity.Retrying(**retry_kwargs)
#    1493     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1495 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File C:\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\google\genai\_api_client.py:1471, in BaseApiClient._request_once(self, http_request, stream)
#    1463 else:
#    1464   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1465       method=http_request.method,
#    1466       url=http_request.url,
#    (...)   1469       timeout=http_request.timeout,
#    1470   )
# -> 1471   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
#    1472 errors.APIError.raise_for_response(response)
#    1473 return HttpResponse(
#    1474     response.headers, response if stream else [response.text]
#    1475 )
#
# File c:\Users\hp\OneDrive\Desktop\delve\.venv\Lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     887 """
#     888 Send a request.
#     889
#    (...)    898 [0]: /advanced/clients/#request-instances
#     899 """
#     900 if self._state == ClientState.CLOSED:
# --> 901     raise RuntimeError("Cannot send a request, as the client has been closed.")
#     903 self._state = ClientState.OPENED
#     904 follow_redirects = (
#     905     self.follow_redirects
#     906     if isinstance(follow_redirects, UseClientDefault)
#     907     else follow_redirects
#     908 )
#
# RuntimeError: Cannot send a request, as the client has been closed.

# %%
# Scratch space — experiment freely below
